# %% [markdown]
# Data Visualization
#
# In this lab, we will cover data visualization techniques using famous library known as matplotlib
#
# Data visualization is essential steps when you want to communicate your findings with your stakeholders or any offer interested parties
#
# Apart from matplotlib there re interested other Data Visualization tools/techniquest available. However learning matplotlib will make your path easier in learning other visualization tools as well.
#
# Matplotlib is a widely used python library for creating static, interactive and animated visualizations. It provides a flexible and easy to use interface for generating various types of plots, charts and graphs.
#
# Plotting in Pandas:
#
# Pandas also has built-in implementation via plot() method.
#
# So plotting in pandas is easy appending plot() methods

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import csv

# %%
import matplotlib.pyplot as plt

# %%
path = 'HR_comma_sep.csv'
df = pd.read_csv(path)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department  salary
# 0                          0      sales     low
# 1                          0      sales  medium
# 2                          0      sales  medium
# 3                          0      sales     low
# 4                          0      sales     low
# ...                      ...        ...     ...
# 14994                      0    support     low
# 14995                      0    support     low
# 14996                      0    support     low
# 14997                      0    support     low
# 14998                      0    support     low
#
# [14999 rows x 10 columns]

# %% [markdown]
# 1. `How does the average satisfaction level change with increasing years of employment? [Line and Scatter Plot]

# %%
print(df['satisfaction_level'])
print('.................')
print(df.satisfaction_level)
# Out:
# 0        0.38
# 1        0.80
# 2        0.11
# 3        0.72
# 4        0.37
#          ...
# 14994    0.40
# 14995    0.37
# 14996    0.37
# 14997    0.11
# 14998    0.37
# Name: satisfaction_level, Length: 14999, dtype: float64
# .................
# 0        0.38
# 1        0.80
# 2        0.11
# 3        0.72
# 4        0.37
#          ...
# 14994    0.40
# 14995    0.37
# 14996    0.37
# 14997    0.11
# 14998    0.37
# Name: satisfaction_level, Length: 14999, dtype: float64

# %%
df['satisfaction_level'].head(10)
# Out:
# 0    0.38
# 1    0.80
# 2    0.11
# 3    0.72
# 4    0.37
# 5    0.41
# 6    0.10
# 7    0.92
# 8    0.89
# 9    0.42
# Name: satisfaction_level, dtype: float64

# %%
df_level = df['satisfaction_level']
df_level
# Out:
# 0        0.38
# 1        0.80
# 2        0.11
# 3        0.72
# 4        0.37
#          ...
# 14994    0.40
# 14995    0.37
# 14996    0.37
# 14997    0.11
# 14998    0.37
# Name: satisfaction_level, Length: 14999, dtype: float64

# %%
df_employment = df['time_spend_company']
df_employment
# Out:
# 0        3
# 1        6
# 2        4
# 3        5
# 4        3
#         ..
# 14994    3
# 14995    3
# 14996    3
# 14997    4
# 14998    3
# Name: time_spend_company, Length: 14999, dtype: int64

# %%
#1. `How does the average satisfaction level change with increasing years of employment? [Line]
df_hr = df.groupby('time_spend_company').agg({'satisfaction_level':'mean'})
df_hr
# Out:
#                     satisfaction_level
# time_spend_company
# 2                             0.697078
# 3                             0.626314
# 4                             0.467517
# 5                             0.610305
# 6                             0.603440
# 7                             0.635957
# 8                             0.665062
# 10                            0.655327

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_hr, marker='o', color='g')
plt.title('Average Satisfaction Vs. Years of Employment')
plt.xlabel('Years of Employment')
plt.ylabel('Average Satisfaction')
plt.grid(True)
plt.show()

# %%
#1. `How does the average satisfaction level change with increasing years of employment? [scatter]
average_satisfaction = df.groupby('time_spend_company')['satisfaction_level'].mean().reset_index()

# Plotting
plt.figure(figsize=(10, 6))

# Scatter plot
plt.scatter(average_satisfaction['time_spend_company'], 
            average_satisfaction['satisfaction_level'], 
            color='blue', 
            alpha=0.6)

# Add labels and title
plt.title('Average Satisfaction Level vs. Years of Employment')
plt.xlabel('Years of Employment')
plt.ylabel('Average Satisfaction Level')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#2.`How many employees have spent a specific number of years (time spent in the company)?` [Bar Plot]
plt.figure(figsize=(10, 5))
x =df['time_spend_company'].value_counts().sort_index()
x.plot(kind='bar', color='g')
plt.title('Average Satisfaction Vs. Years of Employment')
plt.xlabel('Time Spend in Company')
plt.ylabel('Number of employes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Create histogram
plt.hist(data['satisfaction_level'], bins=20, color='skyblue', edgecolor='black')

# Add labels and title
plt.title('Distribution of Satisfaction Levels Among Employees')
plt.xlabel('Satisfaction Level')
plt.ylabel('Frequency')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 plt.figure(figsize=(10, 6))
#       3 # Create histogram
# ----> 4 plt.hist(data['satisfaction_level'], bins=20, color='skyblue', edgecolor='black')
#       6 # Add labels and title
#       7 plt.title('Distribution of Satisfaction Levels Among Employees')
#
# NameError: name 'data' is not defined

# %%
#4. `What is the distribution of work accidents among departments?` [pie plot]
work_accidents_by_dept = df.groupby('Department')['Work_accident'].sum()

# Plotting
plt.figure(figsize=(8, 8))

# Pie chart
plt.pie(work_accidents_by_dept, labels=work_accidents_by_dept.index, autopct='%1.1f%%', startangle=140)

# Add title
plt.title('Distribution of Work Accidents Among Departments')

# Show plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# %%
#5.`What is the distribution of promotions based on departments?`
dis = df.groupby(['Department','promotion_last_5years'])['promotion_last_5years'].count().unstack()
dis
# Out:
# promotion_last_5years       0      1
# Department
# IT                     1224.0    3.0
# RandD                   760.0   27.0
# accounting              753.0   14.0
# hr                      724.0   15.0
# management              561.0   69.0
# marketing               815.0   43.0
# product_mng             902.0    NaN
# sales                  4040.0  100.0
# support                2209.0   20.0
# technical              2692.0   28.0

# %%
dis.plot(kind='bar', color='g')
# plt.title('Average Satisfaction Vs. Years of Employment')
# plt.xlabel('Time Spend in Company')
# plt.ylabel('Number of employes')
# plt.grid(True)
# plt.show()
# Out:
# <AxesSubplot:xlabel='Department'>

# %%
#6. `How does employee satisfaction vary across different departments?` [Box Plot]
plt.figure(figsize=(10, 6))
dept_satisfaction = [df[df['Department'] == dept]['satisfaction_level'] for dept in df['Department'].unique()]
plt.boxplot(dept_satisfaction, labels=df['Department'].unique(), vert=False)
plt.title('Employee Satisfaction Across Different Departments')
plt.ylabel('Department')
plt.xlabel('Satisfaction Level')
plt.xticks(rotation=45)  # Rotate department names for better readability if needed
plt.tight_layout()

# Show plot
plt.show()

# %%
#7. `Figure out employee leaving status (time_spend vs satisfaction_level vs left?`[Bubble Plot]
plt.figure(figsize=(10, 6))

# Define bubble plot
plt.scatter(df['time_spend_company'], 
            df['satisfaction_level'], 
            s=df['left']*100, 
            c=df['left'], 
            cmap='coolwarm', 
            alpha=0.6,
            edgecolors='w',
            linewidth=1)

# Add labels and title
plt.title('Employee Leaving Status based on Time Spent and Satisfaction Level')
plt.xlabel('Time Spent in Company')
plt.ylabel('Satisfaction Level')

# Add a legend
plt.legend(['Not Left', 'Left'], loc='upper right')

# Show plot
plt.grid(True)
plt.colorbar(label='Left')
plt.tight_layout()
plt.show()

# %% [markdown]
# `How many employees have spent a specific number of years (time spent in the company)?`

# %%
df_emp = df['time_spend_company']
df_emp.head
# Out:
# <bound method NDFrame.head of 0        3
# 1        6
# 2        4
# 3        5
# 4        3
#         ..
# 14994    3
# 14995    3
# 14996    3
# 14997    4
# 14998    3
# Name: time_spend_company, Length: 14999, dtype: int64>

# %%
#8.`How are the numerical variables correlated with each other?`
numerical_data = df[['satisfaction_level', 'last_evaluation', 'number_project', 
                       'average_montly_hours', 'time_spend_company']]

# Calculate correlation matrix
correlation_matrix = numerical_data.corr()

# Plotting the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %%
#9. `How to create different scatter plots under single matplotlib figure?`
# Sample data
x1 = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]

x2 = [1, 2, 3, 4, 5]
y2 = [3, 5, 7, 11, 13]

x3 = [1, 2, 3, 4, 5]
y3 = [1, 4, 6, 8, 10]

# Create a new figure
plt.figure(figsize=(10, 6))

# Scatter plot 1
plt.scatter(x1, y1, color='red', label='Plot 1')

# Scatter plot 2
plt.scatter(x2, y2, color='blue', label='Plot 2')

# Scatter plot 3
plt.scatter(x3, y3, color='green', label='Plot 3')

# Add legend
plt.legend()

# Add labels and title
plt.title('Multiple Scatter Plots')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()
