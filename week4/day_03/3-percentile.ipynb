# %% [markdown]
# ## Percentile
# - Percentile is a value below which a certain percentage of observation lie.
# - **Interpretation:**
#   - If student scored in the 75% percentile, they performed better than 75% of the students.
# - **Formulae:**
#   - Percentile rank of x = (#of value below x) / (n)
#
#
# _**`75% percentile means 75% of data points are below the value at 75% percentile`**_

# %%
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\arun\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# WARNING: Ignoring invalid distribution -jango (c:\users\arun\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -jango (c:\users\arun\appdata\local\programs\python\python39\lib\site-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Consider datasets
data = [2, 2, 3, 4, 5, 5, 5, 6, 7,
        8, 8, 8, 8, 8, 9, 9, 10,
        11, 11, 12]

print(data)
# Out:
# [2, 2, 3, 4, 5, 5, 5, 6, 7, 8, 8, 8, 8, 8, 9, 9, 10, 11, 11, 12]

# %%
# sort the data
data = sorted(data)
print(data)
# Out:
# [2, 2, 3, 4, 5, 5, 5, 6, 7, 8, 8, 8, 8, 8, 9, 9, 10, 11, 11, 12]

# %% [markdown]
# **Q. From the above data, what is the percentile ranking of 10?**

# %%
def compute_percentile(sorted_data, value):
  data_len_below_value = len(sorted_data[:sorted_data.index(value)])
  print(data_len_below_value)
  n = len(sorted_data)

  percentile_rank = data_len_below_value / n

  return percentile_rank

# %%
percentile_rank_of_10 = compute_percentile(data, 10)
print(f"Percentile Rank of 10 is: {percentile_rank_of_10}")
# Out:
# 16
# Percentile Rank of 10 is: 0.8

# %% [markdown]
# This means 80% of entire distributions is less than 10.

# %% [markdown]
# **Q. From the above data, what is the percentile ranking of 11**

# %%
percentile_rank_of_11 = compute_percentile(data, 11)

print(f"Percentile Rank of 11 is: {percentile_rank_of_11}")
# Out:
# 17
# Percentile Rank of 11 is: 0.85

# %% [markdown]
# This means 85% of the entire distribution is less than 11.

# %% [markdown]
# **What value exists at percentile ranking of 25%?**
# - 25% percentile is also called as Q1.
# - Q1 is the median of data points between lower item and median.
# - `Formulae:`
#   - value = (percentile / 100) * (n + 1)

# %%
percentile = 25
n = len(data)

value = (percentile / 100) * (n + 1)
print(value)
# Out:
# 5.25

# %% [markdown]
# - Here 5.25 is in between 5th & 6th index.
# - 5th index value = 5
# - 6th index value = 5
#
# - `value = (5 + 5)/2 = `
#
# ```python
# value = (5 + 5)/2  = 5
#
# Hence, value = 5
# ```

# %% [markdown]
# **Compute 25% percentile using Numpy**

# %%
import numpy as np

# 25% percentile
data = [2, 2, 3, 4, 5, 5, 5, 6, 7,
        8, 8, 8, 8, 8, 9, 9, 10,
        11, 11, 12]

value = np.percentile(data, 25)
print(value)
# Out:
# 5.0

# %% [markdown]
# - Hence, we got 25% of the distributions is below 5.0

# %% [markdown]
# ### Box-plot

# %%
data = [2, 2, 3, 4, 5, 5, 5, 6, 7,
        8, 8, 8, 8, 8, 9, 9, 10,
        11, 11, 12, 100]


plt.figure(figsize=(8, 6)) # set the figure size
sns.boxplot(data=data, color='skyblue') # create the box plot
plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box plot of Data points')
plt.show()

# %% [markdown]
# - Here,
#   - Upper Limit is Upper Fence  (Incase of Outliers)
#   - Lower Limit is Lower Fence  (Incase of Outliers)

# %%
# lower_whisker = max(min(data), q1 - 1.5 * iqr)
# upper_whisker = min(max(data), q3 + 1.5 * iqr)
